# %%
import pairTrade
from pairTrade import pairTrade
import pandas as pd
import warnings
import pandas.util.testing as tm
import seaborn as sns
from matplotlib import pyplot as plt
import statsmodels.tsa.stattools as ts 
import statsmodels.formula.api as sm
warnings.filterwarnings('ignore')

## plot
### 外部顯示
# %matplotlib qt 
### 內部
# %matplotlib inline 
plt.figure(figsize = (20,20))

symbols = pd.read_csv(f"/Users/jochien/Documents/MaxRereach/backtrading/rawdata/1D/symbols.csv").symbol.tolist()
df = ((pd.concat([pd.read_csv(f"/Users/jochien/Documents/MaxRereach/backtrading/rawdata/1D/{symbol}.csv", index_col='date', parse_dates=True)
        ['close'].rename(symbol)for symbol in symbols],axis=1,sort=True)))
df = df.loc[:,~df.columns.duplicated()]

# %% [markdown]
# # pair selection

# %%
### 波動度
def volatilityFiliter(df, tradeType, threshold = None, rolling = 20, plot = True):
    """
        Args:
            df (dataframe): raw data 
            tradeType (string): priceSpread, priceRatio, returnSpread, regression. 
            threshold (int):  
            rolling (int):  
    """
    tempList = []
    for A_symbol in df.columns:
        for B_symbol in df.columns:
            if A_symbol != B_symbol:
                if tradeType == 'priceSpread':
                    para = df[A_symbol] - df[B_symbol]
                elif tradeType == 'priceRatio':
                    para = df[A_symbol]/df[B_symbol]
                elif tradeType == 'returnSpread':
                    A_return = df[A_symbol].pct_change()
                    B_return = df[B_symbol].pct_change()
                    para = A_return - B_return
                elif tradeType == 'regression':
                    hedgeRatio=np.full(self.df.shape[0], 0.0)
                    for t in np.arange(self.rolling, len(hedgeRatio)):
                        regress_results=sm.ols(formula="{} ~ {}".format(A_Symbol, B_Symbol), data = df[(t-rolling):t]).fit() # Note this can deal with NaN in top row
                        hedgeRatio[t-1]=regress_results.params[1] ## beta1
                        para = df[A_symbol] - hedgeRatio * df[B_symbol]        
                zscore = (para-para.mean())/para.std()
                signal = ((zscore.shift(1)>0) & (zscore<=0)) | ((zscore.shift(1)<=0) & (zscore>0))
                num = len(signal[signal])
                tempList.append([A_symbol, B_symbol, num])
    result = pd.DataFrame(tempList, columns=['A_symbol', 'B_symbol', 'num']).sort_values('num').reset_index(drop=True)
    print('[average volatility] :', result['num'].mean())
    resultPivot = result.pivot("A_symbol", "B_symbol", "num")
    if plot:
        sns.heatmap(resultPivot, annot = True, xticklabels=1, yticklabels=1)
    if threshold is not None:
        resultFiliter = result[result['num'] >= threshold].reset_index(drop=True)
        return [resultFiliter['A_symbol'][i] + '_' + resultFiliter['B_symbol'][i] for i in range(resultFiliter.shape[0])]
        

## 相關性        
def correlation(df, threshold = None, plot = True):
    result = df.corr(method ='pearson')
    if plot:
        sns.heatmap(df.corr(), annot = True, xticklabels=1, yticklabels=1)

    if threshold is not None:
        resultFiliter = []
        for A_symbol in result.columns:
            for B_symbol in result.columns:
                if result.loc[A_symbol, B_symbol] >= threshold and A_symbol != B_symbol:
                    resultFiliter.append(A_symbol + '_' + B_symbol)
                    
    return resultFiliter

def minimum(df, threshold = None, plot = True):
    tempList = []
    for A_symbol in df.columns:
        for B_symbol in df.columns:
            if A_symbol != B_symbol:
                A_zscore = (df[A_symbol]-df[A_symbol].mean())/df[A_symbol].std()
                B_zscore = (df[B_symbol]-df[B_symbol].mean())/df[B_symbol].std()
                num = ((A_zscore-B_zscore)**2).sum()
                tempList.append([A_symbol, B_symbol, num])
    result = pd.DataFrame(tempList, columns=['A_symbol', 'B_symbol', 'num']).sort_values('num').reset_index(drop=True)
    print('[average minimum] :', result['num'].mean())
    resultPivot = result.pivot("A_symbol", "B_symbol", "num")
    if plot:
        sns.heatmap(resultPivot, annot = True, xticklabels=1, yticklabels=1)
    if threshold is not None:
        resultFiliter = result[result['num'] >= threshold].reset_index(drop=True)
        return [resultFiliter['A_symbol'][i] + '_' + resultFiliter['B_symbol'][i] for i in range(resultFiliter.shape[0])]

def cointegration(df, threshold = None,  plot = True):
    tempList = []
    for A_symbol in df.columns:
        for B_symbol in df.columns:
            if A_symbol != B_symbol:
                coin = ts.coint(df[A_symbol], df[B_symbol])
                tempList.append([A_symbol, B_symbol, coin[1]])
    result = pd.DataFrame(tempList, columns=['A_symbol', 'B_symbol', 'num']).sort_values('num').reset_index(drop=True)
    print('[average minimum] :', result['num'].mean())
    resultPivot = result.pivot("A_symbol", "B_symbol", "num")
    if plot:
        sns.heatmap(resultPivot, annot = True, xticklabels=1, yticklabels=1)
    if threshold is not None:
        resultFiliter = result[result['num'] < threshold].reset_index(drop=True)
        print(resultFiliter)
        return [resultFiliter['A_symbol'][i] + '_' + resultFiliter['B_symbol'][i] for i in range(resultFiliter.shape[0])]

# %%
vol = volatilityFiliter(df, 'priceRatio', threshold = 40, plot = False)
corr = correlation(df, 0.6, plot = False)
mini = minimum(df, 0.6, plot = False)
coin = cointegration(df, 0.05, plot = False)


interSection = list(set(vol) & set(corr) & set(mini) & set(coin))

print("[vol]", len(vol))
print("[corr]", len(corr))
print("[mini]", len(mini))
print("[coin]", len(coin))
print("[interSection]", len(interSection))
# Out:
# [average volatility] : 19.07112375533428
# [average minimum] : 289.9307122918183
# [average minimum] : 0.2601972522035346
#       A_symbol   B_symbol        num
# 0      NEOUSDT  THETAUSDT 0.00000027
# 1     QTUMUSDT    VETUSDT 0.00000058
# 2      XMRUSDT  TFUELUSDT 0.00001445
# 3      ETCUSDT  TFUELUSDT 0.00001623
# 4      XMRUSDT  THETAUSDT 0.00002559
# ..         ...        ...        ...
# 317  TFUELUSDT    HOTUSDT 0.04635175
# 318    XMRUSDT    ONGUSDT 0.04662465
# 319  TFUELUSDT    ONGUSDT 0.04916696
# 320    ETCUSDT    FETUSDT 0.04933253
# 321  THETAUSDT    XLMUSDT 0.04973711
#
# [322 rows x 3 columns]
# [vol] 110
# [corr] 1326
# [mini] 1406
# [coin] 322
# [interSection] 36

# %%
totalPNL.index = df.index

# %%
totalPNL = pd.DataFrame()
totalPNL.index = df.index
temp = 0
for i in interSection:
    A_symbol, B_symbol = i.split('_', 1 )[0], i.split('_', 1 )[1]
    df1 = df[[A_symbol, B_symbol]]
    ratio = pairTrade(df1)
    ratio.indicator(tradeType = 'priceRatio')
    ratio.strategy(strategyType = 'convergence', actionType = 'amount', entry = 1, exit = 0.2, stopLossType = 'trailingStop', trailingProfitTaking = 0.1, trailingStoploss = 0.05)
    totalPNL[i] = ratio.df['total']
    temp += 100000
#     ratio.pplot()
totalPNL['total'] = totalPNL.sum(axis = 1)

plt.figure(figsize = (15,10))
date = totalPNL.index
total = totalPNL['total']
plt.plot(date, total, color = 'b')
plt.ticklabel_format(axis="y", style="plain")
plt.ylabel("equity curve")
# Out:
# ZILUSDT_XLMUSDT 回測結果，場上有單已平倉
# -----------------------------ZILUSDT-XLMUSDT--------------------------
# 初始價格 100000
# 總損益:  -67942.74328351
# 總交易次數:  47
# 平均損益:  -1445.5902826279128
# 勝率:  0.5106382978723404
# 獲利因子:  0.43776592929144276
# 賺賠比:  0.41952568223763265
# 最大資金回落:  76145.60627140578
# 夏普比率:  -0.2700424092259501
# FETUSDT_ADAUSDT 回測結果
# -----------------------------FETUSDT-ADAUSDT--------------------------
# 初始價格 100000
# 總損益:  -22350.53334239
# 總交易次數:  49
# 平均損益:  -456.1333335182447
# 勝率:  0.4489795918367347
# 獲利因子:  0.8220668119804345
# 賺賠比:  1.0089001783396243
# 最大資金回落:  48615.71888987567
# 夏普比率:  -0.0787698322357806
# MITHUSDT_QTUMUSDT 回測結果
# -----------------------------MITHUSDT-QTUMUSDT--------------------------
# 初始價格 100000
# 總損益:  68834.91735835
# 總交易次數:  60
# 平均損益:  1147.2486226392114
# 勝率:  0.5166666666666667
# 獲利因子:  1.3696496834499905
# 賺賠比:  1.2812851877435394
# 最大資金回落:  50285.04950158046
# 夏普比率:  0.10186321658238336
# QTUMUSDT_XRPUSDT 回測結果
# -----------------------------QTUMUSDT-XRPUSDT--------------------------
# 初始價格 100000
# 總損益:  93503.50496268
# 總交易次數:  48
# 平均損益:  1947.9896867224586
# 勝率:  0.6041666666666666
# 獲利因子:  1.622109114441003
# 賺賠比:  1.0627611439441051
# 最大資金回落:  39278.94079453626
# 夏普比率:  0.1781856221128337
# ONGUSDT_IOSTUSDT 回測結果
# -----------------------------ONGUSDT-IOSTUSDT--------------------------
# 初始價格 100000
# 總損益:  150866.49353924
# 總交易次數:  62
# 平均損益:  2433.3305409554114
# 勝率:  0.6290322580645161
# 獲利因子:  1.350111947825018
# 賺賠比:  0.7962198666660362
# 最大資金回落:  196523.14535752282
# 夏普比率:  0.07114811849680665
# BATUSDT_ATOMUSDT 回測結果，場上有單已平倉
# -----------------------------BATUSDT-ATOMUSDT--------------------------
# 初始價格 100000
# 總損益:  41108.48162417
# 總交易次數:  47
# 平均損益:  874.6485451950247
# 勝率:  0.5957446808510638
# 獲利因子:  1.2886425295771624
# 賺賠比:  0.8744360022130744
# 最大資金回落:  37345.73649185678
# 夏普比率:  0.07851387118983853
# XLMUSDT_XMRUSDT 回測結果
# -----------------------------XLMUSDT-XMRUSDT--------------------------
# 初始價格 100000
# 總損益:  -24518.79145479
# 總交易次數:  57
# 平均損益:  -430.1542360488777
# 勝率:  0.5789473684210527
# 獲利因子:  0.7779235425584704
# 賺賠比:  0.5657625764061603
# 最大資金回落:  71603.65415318856
# 夏普比率:  -0.07897590886671713
# BNBUSDT_ENJUSDT 回測結果
# -----------------------------BNBUSDT-ENJUSDT--------------------------
# 初始價格 100000
# 總損益:  -10021.43323661
# 總交易次數:  47
# 平均損益:  -213.22198375759515
# 勝率:  0.48936170212765956
# 獲利因子:  0.91064186471306
# 賺賠比:  0.9502349892658019
# 最大資金回落:  40735.74572531931
# 夏普比率:  -0.04127912178975584
# HOTUSDT_MITHUSDT 回測結果
# -----------------------------HOTUSDT-MITHUSDT--------------------------
# 初始價格 100000
# 總損益:  -8305.62752592
# 總交易次數:  64
# 平均損益:  -129.77543009243368
# 勝率:  0.46875
# 獲利因子:  0.9605576617826302
# 賺賠比:  1.088632016686981
# 最大資金回落:  103451.46558174377
# 夏普比率:  -0.011470661508411499
# ZRXUSDT_ZECUSDT 回測結果，場上有單已平倉
# -----------------------------ZRXUSDT-ZECUSDT--------------------------
# 初始價格 100000
# 總損益:  -31312.67909281
# 總交易次數:  56
# 平均損益:  -559.1549838001608
# 勝率:  0.48214285714285715
# 獲利因子:  0.73156376503344
# 賺賠比:  0.7857536735544356
# 最大資金回落:  36778.52666609465
# 夏普比率:  -0.11335119550935426
# ZECUSDT_ICXUSDT 回測結果，場上有單已平倉
# -----------------------------ZECUSDT-ICXUSDT--------------------------
# 初始價格 100000
# 總損益:  -29451.19739375
# 總交易次數:  53
# 平均損益:  -555.6829696934261
# 勝率:  0.5283018867924528
# 獲利因子:  0.8046875911454152
# 賺賠比:  0.7184710635226921
# 最大資金回落:  44399.103073702325
# 夏普比率:  -0.0893064233522779
# VETUSDT_ONGUSDT 回測結果
# -----------------------------VETUSDT-ONGUSDT--------------------------
# 初始價格 100000
# 總損益:  3645.40603500
# 總交易次數:  54
# 平均損益:  67.50751916664416
# 勝率:  0.48148148148148145
# 獲利因子:  1.0204191297448562
# 賺賠比:  1.098912908955999
# 最大資金回落:  53868.3796229094
# 夏普比率:  0.005694820478246239
# FETUSDT_IOSTUSDT 回測結果
# -----------------------------FETUSDT-IOSTUSDT--------------------------
# 初始價格 100000
# 總損益:  -36749.02926710
# 總交易次數:  59
# 平均損益:  -622.864902832152
# 勝率:  0.4576271186440678
# 獲利因子:  0.7310893263324668
# 賺賠比:  0.866476238616257
# 最大資金回落:  70603.80017406066
# 夏普比率:  -0.1191253774123772
# ZRXUSDT_DASHUSDT 回測結果，場上有單已平倉
# -----------------------------ZRXUSDT-DASHUSDT--------------------------
# 初始價格 100000
# 總損益:  -31006.30450894
# 總交易次數:  51
# 平均損益:  -607.9667550772326
# 勝率:  0.5294117647058824
# 獲利因子:  0.663192264510989
# 賺賠比:  0.5895042351208791
# 最大資金回落:  52531.43471740404
# 夏普比率:  -0.16875753052562564
# LINKUSDT_LTCUSDT 回測結果
# -----------------------------LINKUSDT-LTCUSDT--------------------------
# 初始價格 100000
# 總損益:  16874.06611845
# 總交易次數:  57
# 平均損益:  296.03624769213167
# 勝率:  0.5614035087719298
# 獲利因子:  1.161434909481722
# 賺賠比:  0.9073710230325954
# 最大資金回落:  25275.97542724597
# 夏普比率:  0.059422368515695795
# XMRUSDT_XLMUSDT 回測結果
# -----------------------------XMRUSDT-XLMUSDT--------------------------
# 初始價格 100000
# 總損益:  -28950.19614011
# 總交易次數:  58
# 平均損益:  -499.14131276048863
# 勝率:  0.5862068965517241
# 獲利因子:  0.7322806941665531
# 賺賠比:  0.5169040194116845
# 最大資金回落:  69343.77647870041
# 夏普比率:  -0.09553373612078185
# FETUSDT_CELRUSDT 回測結果
# -----------------------------FETUSDT-CELRUSDT--------------------------
# 初始價格 100000
# 總損益:  90795.86434531
# 總交易次數:  77
# 平均損益:  1179.1670694195502
# 勝率:  0.5194805194805194
# 獲利因子:  1.3415579228055232
# 賺賠比:  1.240941078595109
# 最大資金回落:  74972.30760790844
# 夏普比率:  0.10361321875783779
# QTUMUSDT_IOTAUSDT 回測結果，場上有單已平倉
# -----------------------------QTUMUSDT-IOTAUSDT--------------------------
# 初始價格 100000
# 總損益:  -22135.02673708
# 總交易次數:  51
# 平均損益:  -434.02013209969084
# 勝率:  0.47058823529411764
# 獲利因子:  0.8429079049953035
# 賺賠比:  0.9482713931197165
# 最大資金回落:  61507.42362437601
# 夏普比率:  -0.0646473317365024
# ZRXUSDT_LTCUSDT 回測結果
# -----------------------------ZRXUSDT-LTCUSDT--------------------------
# 初始價格 100000
# 總損益:  -41725.65477154
# 總交易次數:  46
# 平均損益:  -907.079451555189
# 勝率:  0.5217391304347826
# 獲利因子:  0.554460963744672
# 賺賠比:  0.5082558834326161
# 最大資金回落:  62970.73865468333
# 夏普比率:  -0.22298235154017043
# QTUMUSDT_MITHUSDT 回測結果
# -----------------------------QTUMUSDT-MITHUSDT--------------------------
# 初始價格 100000
# 總損益:  59649.62046426
# 總交易次數:  62
# 平均損益:  962.0906526492843
# 勝率:  0.532258064516129
# 獲利因子:  1.3270114731082263
# 賺賠比:  1.1661615975799564
# 最大資金回落:  51740.20514448182
# 夏普比率:  0.09332619452160938
# ZECUSDT_ZRXUSDT 回測結果，場上有單已平倉
# -----------------------------ZECUSDT-ZRXUSDT--------------------------
# 初始價格 100000
# 總損益:  -33022.27699950
# 總交易次數:  56
# 平均損益:  -589.6835178482995
# 勝率:  0.5178571428571429
# 獲利因子:  0.7085776028627658
# 賺賠比:  0.6597101819756785
# 最大資金回落:  40776.20527670327
# 夏普比率:  -0.12643387906148987
# ZECUSDT_NULSUSDT 回測結果
# -----------------------------ZECUSDT-NULSUSDT--------------------------
# 初始價格 100000
# 總損益:  -30929.64279030
# 總交易次數:  53
# 平均損益:  -583.5781658547719
# 勝率:  0.5094339622641509
# 獲利因子:  0.7748223103886883
# 賺賠比:  0.7461251877816999
# 最大資金回落:  41153.01322725162
# 夏普比率:  -0.1025368931544031
# CELRUSDT_BNBUSDT 回測結果，場上有單已平倉
# -----------------------------CELRUSDT-BNBUSDT--------------------------
# 初始價格 100000
# 總損益:  -71607.52728325
# 總交易次數:  44
# 平均損益:  -1627.443801892079
# 勝率:  0.36363636363636365
# 獲利因子:  0.3802628355164133
# 賺賠比:  0.6654599621537234
# 最大資金回落:  83316.41325340832
# 夏普比率:  -0.35144419240762
# ONGUSDT_CELRUSDT 回測結果，場上有單已平倉
# -----------------------------ONGUSDT-CELRUSDT--------------------------
# 初始價格 100000
# 總損益:  81295.25029935
# 總交易次數:  53
# 平均損益:  1533.8726471575912
# 勝率:  0.49056603773584906
# 獲利因子:  1.4017856151500494
# 賺賠比:  1.4557004465019745
# 最大資金回落:  37180.98960262281
# 夏普比率:  0.09766149873036183
# ICXUSDT_DASHUSDT 回測結果，場上有單已平倉
# -----------------------------ICXUSDT-DASHUSDT--------------------------
# 初始價格 100000
# 總損益:  27979.33828616
# 總交易次數:  55
# 平均損益:  508.7152415665626
# 勝率:  0.5272727272727272
# 獲利因子:  1.184299203234509
# 賺賠比:  1.061785492555077
# 最大資金回落:  30541.603399385247
# 夏普比率:  0.0686693760709115
# ZRXUSDT_NULSUSDT 回測結果
# -----------------------------ZRXUSDT-NULSUSDT--------------------------
# 初始價格 100000
# 總損益:  -40647.01081836
# 總交易次數:  50
# 平均損益:  -812.9402163672934
# 勝率:  0.42
# 獲利因子:  0.6330803177713872
# 賺賠比:  0.874253772160487
# 最大資金回落:  58702.0444723016
# 夏普比率:  -0.16640859667895191
# MITHUSDT_ONGUSDT 回測結果，場上有單已平倉
# -----------------------------MITHUSDT-ONGUSDT--------------------------
# 初始價格 100000
# 總損益:  39702.46237288
# 總交易次數:  58
# 平均損益:  684.5252133255036
# 勝率:  0.5862068965517241
# 獲利因子:  1.1206455589789717
# 賺賠比:  0.7910439239851564
# 最大資金回落:  116342.59317112292
# 夏普比率:  0.03884307001623834
# NULSUSDT_ONTUSDT 回測結果
# -----------------------------NULSUSDT-ONTUSDT--------------------------
# 初始價格 100000
# 總損益:  84237.38646888
# 總交易次數:  58
# 平均損益:  1452.3687322221206
# 勝率:  0.6379310344827587
# 獲利因子:  1.836462467245534
# 賺賠比:  1.0423165354636819
# 最大資金回落:  22121.63335450797
# 夏普比率:  0.1418434668431686
# LTCUSDT_DASHUSDT 回測結果，場上有單已平倉
# -----------------------------LTCUSDT-DASHUSDT--------------------------
# 初始價格 100000
# 總損益:  22091.58153283
# 總交易次數:  59
# 平均損益:  374.4335853021552
# 勝率:  0.5932203389830508
# 獲利因子:  1.178732563809395
# 賺賠比:  0.808273758040728
# 最大資金回落:  45670.3910060178
# 夏普比率:  0.056037295746339186
# TRXUSDT_XRPUSDT 回測結果，場上有單已平倉
# -----------------------------TRXUSDT-XRPUSDT--------------------------
# 初始價格 100000
# 總損益:  -47309.09708433
# 總交易次數:  46
# 平均損益:  -1028.458632268009
# 勝率:  0.45652173913043476
# 獲利因子:  0.5448219656281746
# 賺賠比:  0.6485975781287793
# 最大資金回落:  50951.92549267314
# 夏普比率:  -0.1898282462341547
# TRXUSDT_QTUMUSDT 回測結果
# -----------------------------TRXUSDT-QTUMUSDT--------------------------
# 初始價格 100000
# 總損益:  126543.87481168
# 總交易次數:  56
# 平均損益:  2259.7120502086373
# 勝率:  0.625
# 獲利因子:  1.847522902714837
# 賺賠比:  1.1085137416289021
# 最大資金回落:  57405.725684681354
# 夏普比率:  0.21065903090333446
# WAVESUSDT_VETUSDT 回測結果
# -----------------------------WAVESUSDT-VETUSDT--------------------------
# 初始價格 100000
# 總損益:  -42544.21663970
# 總交易次數:  42
# 平均損益:  -1012.9575390404439
# 勝率:  0.40476190476190477
# 獲利因子:  0.5745012052314389
# 賺賠比:  0.8448547135756455
# 最大資金回落:  54927.2620050188
# 夏普比率:  -0.19294277128953127
# VETUSDT_FETUSDT 回測結果，場上有單已平倉
# -----------------------------VETUSDT-FETUSDT--------------------------
# 初始價格 100000
# 總損益:  -31296.43256474
# 總交易次數:  54
# 平均損益:  -579.563566013761
# 勝率:  0.5370370370370371
# 獲利因子:  0.725744600999074
# 賺賠比:  0.6256418974129949
# 最大資金回落:  50795.86992159893
# 夏普比率:  -0.12328242564902467
# CELRUSDT_FETUSDT 回測結果
# -----------------------------CELRUSDT-FETUSDT--------------------------
# 初始價格 100000
# 總損益:  178761.32774789
# 總交易次數:  75
# 平均損益:  2383.484369971915
# 勝率:  0.5733333333333334
# 獲利因子:  1.5866397514470405
# 賺賠比:  1.1807551638675653
# 最大資金回落:  76644.06516547207
# 夏普比率:  0.15487812519048144
# QTUMUSDT_TRXUSDT 回測結果
# -----------------------------QTUMUSDT-TRXUSDT--------------------------
# 初始價格 100000
# 總損益:  135069.24184045
# 總交易次數:  57
# 平均損益:  2369.635821762334
# 勝率:  0.6140350877192983
# 獲利因子:  1.8532342734278142
# 賺賠比:  1.1648901147260546
# 最大資金回落:  52286.81821939512
# 夏普比率:  0.21232029702260427
# ICXUSDT_IOTAUSDT 回測結果
# -----------------------------ICXUSDT-IOTAUSDT--------------------------
# 初始價格 100000
# 總損益:  -1764.67542203
# 總交易次數:  57
# 平均損益:  -30.959217930322904
# 勝率:  0.543859649122807
# 獲利因子:  0.9852786754051943
# 賺賠比:  0.8263627600172597
# 最大資金回落:  30239.514599133225
# 夏普比率:  -0.00574592967765732
# Text(0, 0.5, 'equity curve')

# %%
norm_prices = df.divide(df.iloc[0])

plt.figure(figsize = (15, 10))
plt.plot(norm_prices)
plt.xlabel('days')
plt.title('Performance of cryptocurrencies')
plt.legend(symbols)
plt.show()

result_list = []
for a1 in df.columns:
    for a2 in df.columns:
        if a1 != a2:
            test_result = ts.coint(df[a1], df[a2])
            if test_result[1] < 0.05:
                print(a1 + ' and ' + a2 + ': p-value = ' + str(test_result[1]))
                result_list.append((a1, a2, test_result[1]))

# %%
len(result_list)

# %% [markdown]
# * tradeType(priceRatio, priceSpread, returnSpread, priceRegression)
# * strategyType: convergence 收斂策略, divergence 發散策略
# * actionType: amount等金額購買, unit依比例購買
# * entry 進場條件
# * exit 出場條件
# * signalStopLoss Defaults is None
# * stopLoss 訊號停損
# * singalStopLoss{固定停利停損 : fixedStopLoss, 移動停利停損 : trailingStop, 時間停利停損 : timeStop}
# * stopLossPara 停損參數 : fixedStopLoss 固定停利停損點位, trailingStop 移動停利停損點位, timeStop 時間停利停損時間間隔

# %% [markdown]
# # Ratio

# %% [markdown]
# ### singal stoploss

# %%
# for i in result_list[:1]:
# df1 = df[[i[0], i[1]]]
df1 = df[['BTCUSDT', 'ETHUSDT']]
A = pairTrade(df1)
A.indicator(tradeType = 'priceRatio')
A.strategy(strategyType = 'convergence', actionType = 'amount', entry = 1, exit = 0, signalStopLoss = None)
A.pplot()

# %% [markdown]
# ### stopLoss (fixedProfitTaking)
